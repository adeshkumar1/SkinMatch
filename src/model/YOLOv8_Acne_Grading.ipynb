# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/acnegrades.zip
# Out:
# Archive:  /content/drive/MyDrive/acnegrades.zip
#   inflating: Created Dataset/Level_0/levle0_1.jpg
#   inflating: Created Dataset/Level_0/levle0_100.jpg
#   inflating: Created Dataset/Level_0/levle0_101.jpg
#   inflating: Created Dataset/Level_0/levle0_102.jpg
#   inflating: Created Dataset/Level_0/levle0_103.jpg
#   inflating: Created Dataset/Level_0/levle0_104.jpg
#   inflating: Created Dataset/Level_0/levle0_105.jpg
#   inflating: Created Dataset/Level_0/levle0_106.jpg
#   inflating: Created Dataset/Level_0/levle0_107.jpg
#   inflating: Created Dataset/Level_0/levle0_108.jpg
#   inflating: Created Dataset/Level_0/levle0_109.jpg
#   inflating: Created Dataset/Level_0/levle0_110.jpg
#   inflating: Created Dataset/Level_0/levle0_111.jpg
#   inflating: Created Dataset/Level_0/levle0_112.jpg
#   inflating: Created Dataset/Level_0/levle0_113.jpg
#   inflating: Created Dataset/Level_0/levle0_114.jpg
#   inflating: Created Dataset/Level_0/levle0_115.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 16.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)
#
# OS                  Linux-6.1.58+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# CPU                 Intel Xeon 2.20GHz
# CUDA                12.1
#
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.1.0+cu121>=1.8.0
# torchvision         ✅ 0.16.0+cu121>=0.9.0
# tqdm                ✅ 4.66.2>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0

# %%
# !pip install split_folders

# %%
import splitfolders

input_folder = "/content/Created Dataset"
output = "/content/grading"

splitfolders.ratio(input_folder, output=output, seed=1337, ratio=(.8, .1, .1))
# Out:
# Copying files: 999 files [00:00, 5244.65 files/s]

# %%
# !yolo task=classify mode=train model=yolov8m-cls.pt data=/content/grading epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/classify/train2/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/classify/train2/results.png', width=600)

# %%
# !yolo task=classify mode=predict model=/content/runs/classify/train2/weights/best.pt source=/content/grading/val/Level_0
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-cls summary (fused): 103 layers, 15766499 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/38 /content/grading/val/Level_0/levle0_105.jpg: 640x640 Level_0 0.99, Level_1 0.01, Level_2 0.00, 25.4ms
# image 2/38 /content/grading/val/Level_0/levle0_107.jpg: 640x640 Level_0 0.82, Level_1 0.18, Level_2 0.00, 20.6ms
# image 3/38 /content/grading/val/Level_0/levle0_124.jpg: 640x640 Level_0 0.94, Level_1 0.06, Level_2 0.00, 20.6ms
# image 4/38 /content/grading/val/Level_0/levle0_125.jpg: 640x640 Level_0 0.53, Level_1 0.47, Level_2 0.00, 24.5ms
# image 5/38 /content/grading/val/Level_0/levle0_13.jpg: 640x640 Level_0 0.98, Level_1 0.02, Level_2 0.00, 20.6ms
# image 6/38 /content/grading/val/Level_0/levle0_136.jpg: 640x640 Level_0 0.99, Level_1 0.01, Level_2 0.00, 20.6ms
# image 7/38 /content/grading/val/Level_0/levle0_138.jpg: 640x640 Level_0 0.85, Level_1 0.14, Level_2 0.00, 20.7ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/classify/predict/*.jpg'):
  display(Image(filename=image_path, height=600))
  print("\n")
